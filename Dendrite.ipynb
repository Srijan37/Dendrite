# %%
import json
  
# Opening JSON file
f = open('algoparams_from_ui.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)

for i in data:
    print(i)
  
# Closing file
f.close()
# Out:
# ﻿{
#     "session_name": "test",
#     "session_description": "test",
#     "design_state_data": {
#
#       "session_info" : {
#         "project_id": "1",
#         "experiment_id": "kkkk-11",
#         "dataset":"iris_modified.csv",
#         "session_name": "test",
#         "session_description": "test"
#         },
#
#       "target": {
#         "prediction_type": "Regression",
#         "target": "petal_width",
#         "type":"regression",
#         "partitioning": true
#       },
#       "train": {
#         "policy": "Split the dataset",
#         "time_variable": "sepal_length",
#         "sampling_method": "No sampling(whole data)",
#         "split": "Randomly",
#         "k_fold": false,
#         "train_ratio": 0,
#         "random_seed": 0
#       },
#       "metrics": {
#         "optomize_model_hyperparameters_for": "AUC",
#         "optimize_threshold_for": "F1 Score",
#         "compute_lift_at": 0,
# ...

# %%
type(data)
# Out:
# dict

# %%
from sklearn import design_state_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17800\4098540902.py in <module>
# ----> 1 from sklearn import design_state_data
#
# ImportError: cannot import name 'design_state_data' from 'sklearn' (C:\ProgramData\Anaconda3\lib\site-packages\sklearn\__init__.py)

# %%
target_variable = data['design_state_data']['target']['target']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17800\2159664675.py in <module>
# ----> 1 target_variable = data['design_state_data']['target']['target']
#
# KeyError: 'design_state_data'

# %%
dict(metric = data["design_state_data"]["metrics"]["optomize_model_hyperparameters_for"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17800\387335017.py in <module>
# ----> 1 dict(metric = data["design_state_data"]["metrics"]["optomize_model_hyperparameters_for"])
#
# KeyError: 'design_state_data'

# %%
 for i in data["design_state_data"]:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3684\233353276.py in <module>
# ----> 1 for i in data["design_state_data"]:
#       2        print(i)
#
# KeyError: 'design_state_data'

# %%
for i in data["target"]:
    if "string to match" in i.lower():
        print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3684\340908853.py in <module>
# ----> 1 for i in data["target"]:
#       2     if "string to match" in i.lower():
#       3         print(i)
#
# KeyError: 'target'
